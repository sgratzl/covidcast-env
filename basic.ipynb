# %% [markdown]
# # COVIDCast API

# %%
import covidcast
from matplotlib import pyplot as plt
from datetime import date
# %matplotlib inline

# %%
data = covidcast.signal("fb-survey", "smoothed_cli", date(2020, 5, 6), date(2020, 5, 7),
                        "county")

# %%
data
# Out:
#     geo_value        signal time_value direction      issue  lag     value  \
# 0       01000  smoothed_cli 2020-05-06      None 2020-09-03  120  0.502510
# 1       01003  smoothed_cli 2020-05-06      None 2020-09-03  120  0.925142
# 2       01031  smoothed_cli 2020-05-06      None 2020-09-03  120  0.032859
# 3       01051  smoothed_cli 2020-05-06      None 2020-09-03  120  1.245335
# 4       01069  smoothed_cli 2020-05-06      None 2020-09-03  120  0.898571
# ..        ...           ...        ...       ...        ...  ...       ...
# 955     55141  smoothed_cli 2020-05-07      None 2020-09-03  119  0.433735
# 956     56000  smoothed_cli 2020-05-07      None 2020-09-03  119  0.972483
# 957     56001  smoothed_cli 2020-05-07      None 2020-09-03  119  1.383630
# 958     56021  smoothed_cli 2020-05-07      None 2020-09-03  119  1.534482
# 959     56025  smoothed_cli 2020-05-07      None 2020-09-03  119  1.220871
#
#        stderr  sample_size geo_type data_source
# ...

# %%
covidcast.plot_choropleth(data)
